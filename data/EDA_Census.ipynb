# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
census = pd.read_csv("clean_census.csv")
# Out:
#   File "<ipython-input-39-5f91a8051d63>", line 2
#     census.query('occupation = "Farming-fishing"'')
#                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
sns.catplot(x = "target", y= "age", data = census,kind = "violin")

# %%
grid_violin = sns.catplot(y = "target", x = "age", data = census, kind = "box", row = "education", orient="h", height=1.5, aspect=4)
